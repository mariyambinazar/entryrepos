# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import pandas as pd
employ_data= pd.read_csv('myexcel - myexcel.csv.csv')
employ_data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\MyLap\\entry'

# %%
import numpy as np
random_height=np.random.uniform(150,180,size=len(employ_data))
employ_data['Height']=random_height
employ_data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  176.598507     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  152.518912     235
# 2     John Holland  Boston Celtics      30       SG   27  161.410953     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  178.882202     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  158.625792     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  175.592683     203
# 454      Raul Neto       Utah Jazz      25       PG   24  168.997376     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  160.652749     256
# 456    Jeff Withey       Utah Jazz      24        C   26  167.930039     231
# 457       Priyanka       Utah Jazz      34        C   25  154.457355     231
#
#                College     Salary
# ...

# %%
employ_data['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457         Priyanka
# Name: Name, Length: 458, dtype: object

# %%
employ_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    float64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 32.3+ KB

# %%
employ_data.describe(include="all")
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
employ_data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
employ_data.duplicated().sum()
# Out:
# 0

# %%
employ_data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
team_emp=employ_data['Team'].value_counts()
team_emp
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
percentage=(team_emp/employ_data.shape[0])*100
percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
employ_data['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
ABC_company_position=employ_data.groupby('Position')
for Position,group in ABC_company_position:
  print(f'emloyees in position{Position}:')    
  print(group)
# Out:
# emloyees in positionC:
#                 Name                    Team  Number Position  Age  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25
# 10   Jared Sullinger          Boston Celtics       7        C   24
# 14      Tyler Zeller          Boston Celtics      44        C   26
# 23       Brook Lopez           Brooklyn Nets      11        C   28
# 27        Henry Sims           Brooklyn Nets      14        C   26
# ..               ...                     ...     ...      ...  ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26
# 447      Rudy Gobert               Utah Jazz      27        C   23
# 455     Tibor Pleiss               Utah Jazz      21        C   26
# 456      Jeff Withey               Utah Jazz      24        C   26
# 457         Priyanka               Utah Jazz      34        C   25
#
#          Height  Weight         College      Salary
# 7    163.389367     238         Gonzaga   2165160.0
# ...

# %%
age_group=employ_data['Age'].value_counts().head()
age_group
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# Name: count, dtype: int64

# %%
Group=employ_data.groupby(['Team','Position'])['Salary'].sum()
Group
highest_spend=Group.idxmax()
highest_spend
# Out:
# ('Los Angeles Lakers', 'SF')

# %%
correlation=employ_data[['Age','Salary']].corr()
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt='.2F')
plt.title=('correlation between Age')
